# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Biên dịch file

# %%
# !nvcc "/content/drive/MyDrive/Project/main.cu" -o main

# %% [markdown]
# ### Chạy version chuẩn:

# %%
# !nvprof ./main 0
# Out:
# mnist train number: 60000
# size pic: 28x28
# mnist test number: 10000
# ==3061== NVPROF is profiling process 3061, command: ./main 0
# Basic time: 33248.324219 ms
# ==3061== Profiling application: ./main 0
# ==3061== Profiling result:
#             Type  Time(%)      Time     Calls       Avg       Min       Max  Name
#  GPU activities:   63.46%  16.1856s    120000  134.88us  52.159us  586.56us  DenseForward(float*, float*, float*, float*, int, int)
#                    25.55%  6.51600s    360000  18.100us  17.664us  46.783us  convForward2(float*, int, int, int, float*, int, int, float*, float*, int, int, int)
#                     3.32%  845.78ms     60000  14.096us  13.664us  37.952us  convForward(float*, int, int, float*, int, int, float*, float*, int, int, int)
#                     3.20%  816.99ms     60000  13.616us  13.439us  36.416us  DenseForwardSofmax(float*, float*, float*, float*, int, int)
# ...

# %% [markdown]
# ### Chạy version 1: sử dung SMEM và CMEM

# %%
# !nvprof ./main 1
# Out:
# mnist train number: 60000
# size pic: 28x28
# mnist test number: 10000
# ==3242== NVPROF is profiling process 3242, command: ./main 1
# Ver1 Time : 14644.548828 ms
# ==3242== Profiling application: ./main 1
# ==3242== Profiling result:
#             Type  Time(%)      Time     Calls       Avg       Min       Max  Name
#  GPU activities:   56.75%  4.29418s    360000  11.928us  11.391us  31.264us  convForward2Ver1(float*, int, int, int, float*, int, int, int, int, int)
#                    17.89%  1.35381s    120000  11.281us  5.0880us  46.624us  DenseForward(float*, float*, float*, float*, int, int)
#                    10.34%  782.78ms    120000  6.5230us  4.5440us  20.384us  maxPoolingForward(float*, float*, int, int, int, int)
#                     8.11%  613.49ms     60000  10.224us  9.8230us  27.360us  convForwardVer1(float*, int, int, float*, int, int, int, int, int)
# ...

# %% [markdown]
# ### Chạy vesion 1 với các kích thước blocksize

# %%
# !nvprof ./main 2 1
# Out:
# mnist train number: 60000
# size pic: 28x28
# mnist test number: 10000
# ==3365== NVPROF is profiling process 3365, command: ./main 2 1
# Block Size : 1
# Ver2 Time : 18971.076172 ms
# ==3365== Profiling application: ./main 2 1
# ==3365== Profiling result:
#             Type  Time(%)      Time     Calls       Avg       Min       Max  Name
#  GPU activities:   74.99%  8.27577s    360000  22.988us  21.600us  60.320us  convForward2Ver1(float*, int, int, int, float*, int, int, int, int, int)
#                     6.94%  766.17ms    120000  6.3840us  3.5830us  22.368us  DenseForward(float*, float*, float*, float*, int, int)
#                     6.84%  754.85ms    120000  6.2900us  3.9350us  20.768us  maxPoolingForward(float*, float*, int, int, int, int)
#                     6.51%  718.89ms     60000  11.981us  11.199us  32.736us  convForwardVer1(float*, int, int, float*, int, int, int, int, int)
# ...

# %%
# !nvprof ./main 2 2
# Out:
# mnist train number: 60000
# size pic: 28x28
# mnist test number: 10000
# ==3496== NVPROF is profiling process 3496, command: ./main 2 2
# Block Size : 2
# Ver2 Time : 14179.469727 ms
# ==3496== Profiling application: ./main 2 2
# ==3496== Profiling result:
#             Type  Time(%)      Time     Calls       Avg       Min       Max  Name
#  GPU activities:   63.76%  4.06123s    360000  11.281us  10.783us  29.088us  convForward2Ver1(float*, int, int, int, float*, int, int, int, int, int)
#                    11.75%  748.17ms    120000  6.2340us  3.8080us  20.288us  maxPoolingForward(float*, float*, int, int, int, int)
#                    10.76%  685.52ms    120000  5.7120us  3.2630us  19.936us  DenseForward(float*, float*, float*, float*, int, int)
#                     5.50%  350.36ms     60000  5.8390us  5.6310us  15.968us  convForwardVer1(float*, int, int, float*, int, int, int, int, int)
# ...

# %%
# !nvprof ./main 2 4
# Out:
# mnist train number: 60000
# size pic: 28x28
# mnist test number: 10000
# ==3607== NVPROF is profiling process 3607, command: ./main 2 4
# Block Size : 4
# Ver2 Time : 12875.285156 ms
# ==3607== Profiling application: ./main 2 4
# ==3607== Profiling result:
#             Type  Time(%)      Time     Calls       Avg       Min       Max  Name
#  GPU activities:   31.69%  1.10443s    120000  9.2030us  4.8310us  20.544us  maxPoolingForward(float*, float*, int, int, int, int)
#                    28.01%  976.21ms    120000  8.1350us  3.9040us  19.168us  DenseForward(float*, float*, float*, float*, int, int)
#                    16.95%  590.48ms    360000  1.6400us  1.3430us  2.6560us  convForward2Ver1(float*, int, int, int, float*, int, int, int, int, int)
#                     6.88%  239.83ms     60000  3.9970us  3.3270us  6.5600us  DenseForwardSofmax(float*, float*, float*, float*, int, int)
#                     5.01%  174.52ms    120000  1.4540us     672ns  2.4320us  [CUDA memcpy DtoH]
# ...

# %%
# !nvprof ./main 2 8
# Out:
# mnist train number: 60000
# size pic: 28x28
# mnist test number: 10000
# ==3731== NVPROF is profiling process 3731, command: ./main 2 8
# Block Size : 8
# Ver2 Time : 14550.713867 ms
# ==3731== Profiling application: ./main 2 8
# ==3731== Profiling result:
#             Type  Time(%)      Time     Calls       Avg       Min       Max  Name
#  GPU activities:   62.48%  4.03770s    360000  11.215us  10.783us  28.768us  convForward2Ver1(float*, int, int, int, float*, int, int, int, int, int)
#                    12.22%  789.98ms    120000  6.5830us  3.4230us  23.200us  DenseForward(float*, float*, float*, float*, int, int)
#                    11.82%  763.94ms    120000  6.3660us  3.9030us  20.608us  maxPoolingForward(float*, float*, int, int, int, int)
#                     5.27%  340.66ms     60000  5.6770us  5.4710us  15.712us  convForwardVer1(float*, int, int, float*, int, int, int, int, int)
# ...

# %%
# !nvprof ./main 2 16
# Out:
# mnist train number: 60000
# size pic: 28x28
# mnist test number: 10000
# ==3840== NVPROF is profiling process 3840, command: ./main 2 16
# Block Size : 16
# Ver2 Time : 16332.222656 ms
# ==3840== Profiling application: ./main 2 16
# ==3840== Profiling result:
#             Type  Time(%)      Time     Calls       Avg       Min       Max  Name
#  GPU activities:   49.54%  4.19027s    360000  11.639us  11.103us  29.887us  convForward2Ver1(float*, int, int, int, float*, int, int, int, int, int)
#                    29.32%  2.48001s    120000  20.666us  8.3200us  85.152us  DenseForward(float*, float*, float*, float*, int, int)
#                     9.26%  782.92ms    120000  6.5240us  4.2230us  20.384us  maxPoolingForward(float*, float*, int, int, int, int)
#                     4.26%  360.20ms     60000  6.0030us  5.7590us  16.064us  convForwardVer1(float*, int, int, float*, int, int, int, int, int)
# ...

# %%
# !nvprof ./main 2 32
# Out:
# mnist train number: 60000
# size pic: 28x28
# mnist test number: 10000
# ==3961== NVPROF is profiling process 3961, command: ./main 2 32
# Block Size : 32
# Ver2 Time : 31224.767578 ms
# ==3961== Profiling application: ./main 2 32
# ==3961== Profiling result:
#             Type  Time(%)      Time     Calls       Avg       Min       Max  Name
#  GPU activities:   70.42%  16.2060s    120000  135.05us  52.159us  586.52us  DenseForward(float*, float*, float*, float*, int, int)
#                    18.46%  4.24865s    360000  11.801us  11.360us  31.167us  convForward2Ver1(float*, int, int, int, float*, int, int, int, int, int)
#                     3.55%  817.75ms     60000  13.629us  13.439us  36.416us  DenseForwardSofmax(float*, float*, float*, float*, int, int)
#                     3.38%  778.27ms    120000  6.4850us  4.6070us  20.416us  maxPoolingForward(float*, float*, int, int, int, int)
# ...
